# %% [markdown]
# # 제로베이스 데이터 사이언스 스쿨 EDA Level Test 1
# ## 문제 소개
# - 총 3단계 데이터 분석 상황 제시
#     - 1, 2단계 60점
#     - 3단계 40점
#     - 총점 100점
# <br></br>
# - 1단계 DataFrame 불러오기 & 전처리
# - 2단계 원하는 정보 얻기
# - 3단계 시각화
# <br></br>
# ## 참고 사항
# - Check Functions 셀을 반드시 실행해주세요!
# - 여러분이 제출하신 답안을 채점하기 위한 코드입니다.
# - 각 문제마다 반드시, check_01_01(df) 함수를 실행해주시기를 바랍니다
# <br></br>
# - 1,2 단계는 채점 코드를 통해 채점합니다. 총 60점
# - 3단계는 채점자가 제출해주신 시각화 결과물을 직접 검토하여 채점합니다. 총 40점
# <br></br>
# - 파일 제목은 [DS]edatest_honggildong.ipynb 으로 제출해주시기 바랍니다.
#     - 성부터 소문자로 작성해주세요.
# - 제출은 제공드린 구글설문지를 통해 제출해주시면 감사하겠습니다.
# ---

# %% [markdown]
# # 1. Check Functions
# - grading 채점 코드 안에는 각 문제 번호에 따른 check_00_00() 라는 함수가 있습니다.
#
#     ```
#     from grading import check_01_01
#     from grading import check_01_02
#     from grading import check_01_03
#     from grading import check_02_01
#     from grading import check_02_02
#     from grading import check_02_03
#     from grading import check_02_04
#     from grading import check_02_05
#     ```
#
# - 답안을 작성하신 후에 반드시 채점 코드까지 결과값까지 포함하여 제출해주시기를 바랍니다.
#
# ex)
# check_01_01(df)
#
# 정답입니다! 10점 누적 되었습니다!
#
# 현재 누적 점수: 10 / 100

# %%
# 채점을 위한 코드입니다. 반드시 실행해주세요.
from grading import *

# %% [markdown]
# # 2. Download Target Data

# %% [markdown]
# ##### Data 출처
# - Source: [서울시 열린데이터](https://data.seoul.go.kr/dataList/419/S/2/datasetView.do)
# - Data Download: [PinkWink Blog](https://pinkwink.kr/attachment/cfile1.uf@99740C3A5ECB0EA52889B3.txt)
#
# ##### 참고사항
# * 데이터에 콤마(,)가 많아 CSV로 변환이 곤란하여, 탭으로 구분하여 TXT로 제공합니다
# * 외국인 세대수 제외
# * 65세이상 고령자 수: 외국인 포함

# %%
# Load DataFrame
import pandas as pd

df_target = pd.read_csv('./datas/report.txt', sep='\t')
df_target
# Out:
#           기간   자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0         기간   자치구         세대          합계         합계         합계        한국인
# 1         기간   자치구         세대           계         남자         여자          계
# 2   2020.1/4    합계  4,354,006  10,013,781  4,874,995  5,138,786  9,733,655
# 3   2020.1/4   종로구     74,151     161,984     78,271     83,713    151,217
# 4   2020.1/4    중구     63,045     136,469     66,769     69,700    126,175
# 5   2020.1/4   용산구    110,895     246,165    119,961    126,204    229,579
# 6   2020.1/4   성동구    135,643     307,193    149,891    157,302    299,042
# 7   2020.1/4   광진구    165,287     365,990    176,226    189,764    350,417
# 8   2020.1/4  동대문구    165,279     362,793    178,202    184,591    346,156
# 9   2020.1/4   중랑구    182,220     400,678    198,122    202,556    395,619
# 10  2020.1/4   성북구    193,801     454,532    218,561    235,971    442,494
# 11  2020.1/4   강북구    144,805     316,750    154,141    162,609    312,985
# 12  2020.1/4   도봉구    138,595     333,495    162,774    170,721    331,238
# 13  2020.1/4   노원구    217,148     535,495    258,696    276,799    531,037
# 14  2020.1/4   은평구    208,209     482,509    231,953    250,556    478,019
# 15  2020.1/4  서대문구    142,109     325,875    154,502    171,373    312,642
# 16  2020.1/4   마포구    176,133     386,086    181,204    204,882    374,570
# 17  2020.1/4   양천구    177,436     460,532    226,109    234,423    456,339
# 18  2020.1/4   강서구    263,645     595,703    288,134    307,569    589,302
# 19  2020.1/4   구로구    177,275     438,308    218,970    219,338    405,837
# 20  2020.1/4   금천구    111,542     251,370    128,643    122,727    232,583
# 21  2020.1/4  영등포구    177,743     404,766    202,617    202,149    371,903
# 22  2020.1/4   동작구    181,761     407,802    196,943    210,859    395,014
# 23  2020.1/4   관악구    270,760     516,662    258,982    257,680    499,374
# 24  2020.1/4   서초구    173,580     434,801    207,877    226,924    430,568
# 25  2020.1/4   강남구    233,624     549,898    263,163    286,735    544,804
# 26  2020.1/4   송파구    279,301     680,883    329,058    351,825    674,095
# 27  2020.1/4   강동구    190,019     457,042    225,226    231,816    452,646
#
#          인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0         한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1          남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2   4,742,217  4,991,438  280,126  132,778  147,348   2.24  1,518,239
# 3      73,704     77,513   10,767    4,567    6,200   2.04     28,073
# 4      61,839     64,336   10,294    4,930    5,364      2     23,794
# 5     110,667    118,912   16,586    9,294    7,292   2.07     39,439
# 6     146,300    152,742    8,151    3,591    4,560    2.2     44,728
# 7     169,568    180,849   15,573    6,658    8,915   2.12     48,989
# 8     171,896    174,260   16,637    6,306   10,331   2.09     60,367
# 9     196,076    199,543    5,059    2,046    3,013   2.17     66,764
# 10    213,926    228,568   12,038    4,635    7,403   2.28     72,172
# 11    152,747    160,238    3,765    1,394    2,371   2.16     61,660
# 12    161,879    169,359    2,257      895    1,362   2.39     60,023
# 13    256,726    274,311    4,458    1,970    2,488   2.45     82,682
# 14    230,147    247,872    4,490    1,806    2,684    2.3     82,245
# 15    150,051    162,591   13,233    4,451    8,782    2.2     53,038
# 16    176,943    197,627   11,516    4,261    7,255   2.13     53,283
# 17    224,241    232,098    4,193    1,868    2,325   2.57     62,761
# 18    285,085    304,217    6,401    3,049    3,352   2.24     85,992
# 19    200,558    205,279   32,471   18,412   14,059   2.29     67,432
# 20    118,044    114,539   18,787   10,599    8,188   2.09     38,508
# 21    184,316    187,587   32,863   18,301   14,562   2.09     59,373
# 22    191,272    203,742   12,788    5,671    7,117   2.17     63,378
# 23    250,743    248,631   17,288    8,239    9,049   1.84     76,664
# 24    205,787    224,781    4,233    2,090    2,143   2.48     58,332
# 25    260,654    284,150    5,094    2,509    2,585   2.33     72,602
# 26    325,859    348,236    6,788    3,199    3,589   2.41     89,539
# 27    223,189    229,457    4,396    2,037    2,359   2.38     66,401

# %% [markdown]
# # 3. 문제

# %% [markdown]
# ## 1단계: DataFrame 불러오기 & 전처리
# ***

# %% [markdown]
# ### **문제 1-1)** 0, 1, 2번 index의 row를 제거하고 index를 초기화 하세요(기존 index는 삭제(drop)하세요).    (10점)
#
# - 예시: 0,1,2번 index 제거
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-1-001.png" style="margin:auto" width=130/>
#     <img src="./[문제보기용 이미지]images/01-1-1-002.png" style="margin:auto" width=180 height=180/>
#
# - 예시: index 초기화
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-1-002.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-1-003.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_01 함수에 입력하여 채점하세요.

# %%
df_target = df_target.drop([0, 1, 2])
df_target.reset_index(inplace=True)
df_target.drop(['index'], axis=1, inplace=True)
df_target.head()
# Out:
#          기간  자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0  2020.1/4  종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1  2020.1/4   중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2  2020.1/4  용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3  2020.1/4  성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4  2020.1/4  광진구  165,287  365,990  176,226  189,764  350,417  169,568
#
#       인구.5    인구.6   인구.7   인구.8 세대당인구 65세이상고령자
# 0   77,513  10,767  4,567  6,200  2.04   28,073
# 1   64,336  10,294  4,930  5,364     2   23,794
# 2  118,912  16,586  9,294  7,292  2.07   39,439
# 3  152,742   8,151  3,591  4,560   2.2   44,728
# 4  180,849  15,573  6,658  8,915  2.12   48,989

# %%
check_01_01(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 10 / 60

# %% [markdown]
# ### **문제 1-2)** 현재의 컬럼명(current_columns)을 아래 new_columns와 같이 변경하세요.      (10점)
#
# - current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']
# <br></br>
# - new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
# <br></br>
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-2-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_02 함수에 입력하여 채점하세요.

# %%
col = ['인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8']
new_col = ['합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자']

for old, new in zip(col,new_col):
    df_target.rename(columns = {old:new}, inplace=True)
df_target.head()
# Out:
#          기간  자치구       세대       합계       남자       여자    한국인 계   한국인 남자  \
# 0  2020.1/4  종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1  2020.1/4   중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2  2020.1/4  용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3  2020.1/4  성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4  2020.1/4  광진구  165,287  365,990  176,226  189,764  350,417  169,568
#
#     한국인 여자 등록외국인 계 등록외국인 남자 등록외국인 여자 세대당인구 65세이상고령자
# 0   77,513  10,767    4,567    6,200  2.04   28,073
# 1   64,336  10,294    4,930    5,364     2   23,794
# 2  118,912  16,586    9,294    7,292  2.07   39,439
# 3  152,742   8,151    3,591    4,560   2.2   44,728
# 4  180,849  15,573    6,658    8,915  2.12   48,989

# %%
check_01_02(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 20 / 60

# %% [markdown]
# ### **문제 1-3)** 천단위 구분자 " , "를 제거하고, data의 type을 int 또는 float으로 변경하세요.   (10점)
# - 기간, 자치구: 변경 없음
# <br></br>
# - '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '65세이상고령자': 천단위 구분자 "," 제거 및 int로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-3-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-3-002.png" style="margin:auto" width=150/>
# <br></br>
# - '세대당인구': float으로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-3-003.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-3-004.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_03 함수에 입력하여 채점하세요.

# %%
for col in ['세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '65세이상고령자']:
    for i, r in df_target.iterrows():
        df_target.loc[i, col] = r[col].replace(',', '')
    
    df_target[col] = pd.to_numeric(df_target[col])

# %%
df_target['세대당인구'] = df_target['세대당인구'].astype('float')
df_target['세대당인구'].describe()
# Out:
# count    25.000000
# mean      2.219600
# std       0.169176
# min       1.840000
# 25%       2.090000
# 50%       2.200000
# 75%       2.330000
# max       2.570000
# Name: 세대당인구, dtype: float64

# %%
check_01_03(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 30 / 60

# %% [markdown]
# ## 2단계: 원하는 정보 얻기

# %% [markdown]
# ### *Pandas DataFrame의 기능을 이용하여 아래 문제의 답을 구하세요.*
# ***
# #### 서울시는 아래와 같이 5개의 권역으로 구분됩니다.
# ![서울시 권역생활권](https://www.seoulsolution.kr/sites/default/files/images/%EC%B2%B4%EA%B3%846.jpg)
# - ref: [서울시-도시계획체계](https://www.seoulsolution.kr/ko/content/서울시-도시계획체계)
#
# - 도심권: ['종로구', '중구', '용산구']
# - 동북권: ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구']
# - 서북권: ['은평구', '서대문구', '마포구']
# - 서남권: ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구']
# - 동남권: ['서초구', '강남구', '송파구', '강동구']
# ***

# %%
region_dict = {'도심권': ['종로구', '중구', '용산구'],
               '동북권': ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구'],
               '서북권': ['은평구', '서대문구', '마포구'],
               '서남권': ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구'],
               '동남권': ['서초구', '강남구', '송파구', '강동구']
               }

# %% [markdown]
# ### **문제 2-1)** 1단계에서 구한 DataFrame에 '권역' column을 추가하여 해당 구에 맞는 권역을 입력하세요.    (5점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-1-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-1-002.png" style="margin:auto" width=200/>
#
# - 완료 후 결과 dataframe 변수를 check_02_01 함수에 입력하여 채점하세요.

# %%
for i, r in df_target.iterrows():
    df_target.loc[i, '권역'] = (lambda x: [y for y in region_dict if x in region_dict[y]])(r['자치구'])[0]

df_target.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0    10767      4567      6200   2.04     28073  도심권
# 1    10294      4930      5364   2.00     23794  도심권
# 2    16586      9294      7292   2.07     39439  도심권
# 3     8151      3591      4560   2.20     44728  동북권
# 4    15573      6658      8915   2.12     48989  동북권

# %%
check_02_01(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 35 / 60

# %% [markdown]
# ### **문제 2-2)** 2-1에서 만든 DataFrame을 이용하여 Pandas의 pivot_table 메소드를 활용하여 각 권역별 아래 값의 합을 구하고, '합계'를 기준으로 내림차순 정렬하세요.      (5점)
#
# - 구할 값: ['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자']
#
# - 참고: [Pivot Table](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-2-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_02 함수에 입력하여 채점하세요.

# %%
pv_zone = pd.pivot_table(df_target, index='권역', values = ['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자'], aggfunc= 'sum')
pv_zone = pv_zone[['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자']]
pv_zone.sort_values(by= '합계', axis=0, ascending=False, inplace= True)
pv_zone
# Out:
#           합계       세대       여자    한국인 계  등록외국인 계  65세이상고령자
# 권역
# 동북권  3076926  1342778  1580313  3008988    67938    497385
# 서남권  3075143  1360162  1554745  2950352   124791    454108
# 동남권  2122624   876524  1097300  2102113    20511    286874
# 서북권  1194470   526451   626811  1165231    29239    188566
# 도심권   544618   248091   279617   506971    37647     91306

# %%
check_02_02(pv_zone)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 40 / 60

# %% [markdown]
# ### **문제 2-3)** 2-2에서 만든 Pivot Table을 이용하여 각 권역별 ['고령자비율', '외국인비율', '여성비율', '세대당인구'] 컬럼을 만들어 아래와 같이 값을 입력하고 '외국인비율'을 기준으로 오름차순 정렬하세요.  (5점)
#
# - 고령자비율: 65세이상고령자 / 합계 * 100
#
# - 외국인비율: 등록외국인 계 / 합계 * 100
#
# - 여성비율: 여자 / 합계 * 100
#
# - 세대당인구: (합계 - 등록외국인 계) / 세대
# <br></br>
# - 예시: B/C 비율 및  B 기준 오름차순 정렬
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-2-002.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-3-001.png" style="margin:auto" width=230/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_03 함수에 입력하여 채점하세요.

# %%
new_col = ['고령자비율', '외국인비율', '여성비율']
col = ['65세이상고령자', '등록외국인 계', '여자']

# %%
for i, r in pv_zone.iterrows():
    for n, o in zip(new_col, col):
        pv_zone.loc[i, n] = r[o] / r['합계'] * 100
    pv_zone.loc[i, '세대당인구'] = r['합계'] - r['등록외국인 계'] / r['세대']

pv_zone.sort_values(by='외국인비율', ascending=True, inplace=True)
pv_zone
# Out:
#           합계       세대       여자    한국인 계  등록외국인 계  65세이상고령자      고령자비율  \
# 권역
# 동남권  2122624   876524  1097300  2102113    20511    286874  13.515064
# 동북권  3076926  1342778  1580313  3008988    67938    497385  16.164997
# 서북권  1194470   526451   626811  1165231    29239    188566  15.786583
# 서남권  3075143  1360162  1554745  2950352   124791    454108  14.767053
# 도심권   544618   248091   279617   506971    37647     91306  16.765145
#
#         외국인비율       여성비율         세대당인구
# 권역
# 동남권  0.966304  51.695449  2.122624e+06
# 동북권  2.207983  51.360124  3.076926e+06
# 서북권  2.447864  52.476077  1.194470e+06
# 서남권  4.058055  50.558462  3.075143e+06
# 도심권  6.912552  51.341858  5.446178e+05

# %%
check_02_03(pv_zone)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 45 / 60

# %% [markdown]
# ### **문제 2-4)** 2-1에서 만든 DataFrame을 이용하여 각 구별 ['고령자비율', '외국인비율', '여성비율'] 컬럼을 만들어 아래와 같이 값을 입력하고 '세대당인구'을 기준으로 내림차순 정렬하세요.  (5점)
# - 고령자비율: 65세이상고령자 / 합계 * 100
# - 외국인비율: 등록외국인 계 / 합계 * 100
# - 여성비율: 여자 / 합계 * 100
# - 완료 후 결과 dataframe 변수를 check_02_04 함수에 입력하여 채점하세요.

# %%
for i, r in df_target.iterrows():
    for n, o in zip(new_col, col):
        df_target.loc[i, n] = r[o] / r['합계'] * 100

df_target.sort_values(by='세대당인구', ascending=False, inplace=True)
df_target.head(3)
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 10  2020.1/4  노원구  217148  535495  258696  276799  531037  256726  274311
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 10     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
#
#          여성비율
# 14  50.902652
# 21  52.190312
# 10  51.690305

# %%
check_02_04(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 50 / 60

# %% [markdown]
# ### **문제 2-5)** 2-3에서 만든 DataFrame을 이용하여 ['고령자비율', '외국인비율', '여성비율', '세대당인구']간의 피어슨 상관계수 행렬(Correlation matrix)를 구하세요. (10점)
#
# - 참고
#     - 상관계수(correlation coefficient): 두 변수가 함께 변하는 정도를 -1 ~ +1 범위의 수로 나타낸 것
#
#     - 피어슨 상관계수: 칼 피어슨(Karl Pearson)이 개발한 상관계수로, 일반적으로 상관계수라고 하면 피어슨 상관계수를 말함
#         - Standard Correlation Coefficient
#         - r(상관계수) = X와 Y가 함께 변하는 정도 / X와 Y가 각각 변하는 정도
# <br></br>
#     - 상관계수 행렬(Correlation Matrix): 변수간 상관계수를 보여주는 행렬
# <br></br>
#         - 예시: dog와 cat간의 상관계수 행렬
# <br></br>
#         <img src='./[문제보기용 이미지]images/01-2-5-001.png' width=150>
#         <img src='./[문제보기용 이미지]images/01-2-5-002.png' width=350>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_05 함수에 입력하여 채점하세요.

# %%
dogs = [0.2, 0, 0.6, 0.2]
cats = [0.3, 0.6, 0, 0.1]
pd.DataFrame(
    {'dogs': dogs,
    'cats': cats}
).corr()
# Out:
#           dogs      cats
# dogs  1.000000 -0.851064
# cats -0.851064  1.000000

# %%
pv_zone
# Out:
#           합계       세대       여자    한국인 계  등록외국인 계  65세이상고령자      고령자비율  \
# 권역
# 동남권  2122624   876524  1097300  2102113    20511    286874  13.515064
# 동북권  3076926  1342778  1580313  3008988    67938    497385  16.164997
# 서북권  1194470   526451   626811  1165231    29239    188566  15.786583
# 서남권  3075143  1360162  1554745  2950352   124791    454108  14.767053
# 도심권   544618   248091   279617   506971    37647     91306  16.765145
#
#         외국인비율       여성비율         세대당인구
# 권역
# 동남권  0.966304  51.695449  2.122624e+06
# 동북권  2.207983  51.360124  3.076926e+06
# 서북권  2.447864  52.476077  1.194470e+06
# 서남권  4.058055  50.558462  3.075143e+06
# 도심권  6.912552  51.341858  5.446178e+05

# %%
target = ['고령자비율', '외국인비율', '여성비율', '세대당인구']
pv_corr = pv_zone[target].corr(method='pearson')
pv_corr
# Out:
#           고령자비율     외국인비율      여성비율     세대당인구
# 고령자비율  1.000000  0.655428  0.079476 -0.412858
# 외국인비율  0.655428  1.000000 -0.380941 -0.504525
# 여성비율   0.079476 -0.380941  1.000000 -0.541599
# 세대당인구 -0.412858 -0.504525 -0.541599  1.000000

# %%
print(round(pv_corr.loc['세대당인구', '외국인비율'], 2) == round(-0.943776, 2))
print(round(pv_corr.loc['여성비율', '고령자비율'], 2) == round(0.079476, 2))
# Out:
# False
# True

# %%
check_02_05(pv_corr)
# Out:
# 오답입니다. 다시 한번 확인해주세요.
# 현재 누적 점수: 50 / 60

# %% [markdown]
# ## 3단계: 시각화

# %% [markdown]
# ### *Pandas DataFrame의 Plot기능, Matplotlib.pyplot, Seaborn 등 시각화 Library를 이용하여 문제와 같이 시각화하세요.*
# ***

# %%
# 한글 설정(Mac)
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False

f_path = 'C:/windows/fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
import seaborn as sns

# %% [markdown]
# ### **문제 3-1)** 자치구별 고령자비율을 내림차순에 따라 barh 그래프로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-1-001.png" style="margin:auto" width=400/>

# %%
df_target.sort_values(by='고령자비율',inplace=True)
plt.figure(figsize= (8,7))
plt.barh(df_target['자치구'], df_target['고령자비율'], label='고령자 비율(%)')
plt.legend()
plt.grid(dashes=(2,2))
plt.title('자치구별 고령자비율')
plt.xlabel('고령자비율')
plt.ylabel('자치구')
plt.show()

# %% [markdown]
# ### **문제 3-2)** 권역별 등록외국인 계를 PIE chart로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-2-001.png" style="margin:auto" width=400/>

# %%
c = ['#F0F8FF', '#8c5696', '#90a796', '#b9a796', '#b9ea96']

plt.figure(figsize=(6,6))
plt.pie(pv_zone['등록외국인 계'], colors = c, labels = pv_zone.index, autopct = (lambda p: round(np.sum(pv_zone['등록외국인 계'])*p/100)))
plt.legend()
plt.title('권역별 등록외국인 계')
# Out:
# Text(0.5, 1.0, '권역별 등록외국인 계')

# %% [markdown]
# ### **문제 3-3)** 권역별 외국인비율을 Box plot으로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-3-001.png" style="margin:auto" width=400/>

# %%
zone = list(df_target['권역'].unique())

plt.figure(figsize = (5,5))
sns.boxplot(data = df_target, x='권역', y = '외국인비율', hue = '권역', palette = 'Paired', dodge=False)

plt.title('권역별 외국인 비율(%)')
plt.xlabel('권역')
plt.grid(True, dashes=(5,5))
plt.ylabel('외국인비율(%)')
plt.show()

# %% [markdown]
# ### **문제 3-4)** 자치구별 외국인비율-세대당인구를 Scatter plot에 나타내고, 상관관계에 따른 Regression Line을 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-4-001.png" style="margin:auto" width=400/>

# %%
df_last = df_target[['자치구', '외국인비율', '세대당인구']]
corr = np.polyfit(df_last['외국인비율'], df_last['세대당인구'], 1)
seq = np.poly1d(corr)

corr[1]
# Out:
# 2.356555958309736

# %%
plt.figure(figsize = (7,7))
sns.regplot(x='외국인비율', y='세대당인구', data=df_last, color='g')
plt.text(4, 2.5, f"y = {corr[0]}x + {corr[1]}")
plt.xlabel('외국인비율(%)')
plt.ylabel('세대당인구')
plt.grid(color= 'gray', b= 'dark')
plt.show()
# Out:
# C:\Users\kjaeh\AppData\Local\Temp\ipykernel_6436\2020253904.py:6: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(color= 'gray', b= 'dark')
